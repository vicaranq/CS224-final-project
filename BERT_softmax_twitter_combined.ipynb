# %% [markdown]
# # Use BERT Representations with LogisticRegression Softmax Classifier

# %%
from collections import Counter
import os
import numpy as np
import pandas as pd
import torch
from torch import nn, optim
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from transformers import BertTokenizer, BertModel, BertForSequenceClassification


import dataset
import vsm
import sst

# %%
TWITTER = 2
TWITTER_AIRLINES = 3
TWITTER_APPLE = 4

# %%
twitter_train, twitter_validate, twitter_test =  dataset.dataset_reader(TWITTER)
[twitter_train, twitter_validate, twitter_test] = list(map(lambda ds : dataset.prune_columns(2, ds), [twitter_train, twitter_validate, twitter_test]))

# %%
airline_train, airline_validate, airline_test =  dataset.dataset_reader(TWITTER_AIRLINES)
[airline_train, airline_validate, airline_test] = list(map(lambda ds : dataset.prune_columns(3, ds), [airline_train, airline_validate, airline_test]))

# %%
apple_train, apple_validate, apple_test =  dataset.dataset_reader(TWITTER_APPLE)
[apple_train, apple_validate, apple_test] = list(map(lambda ds : dataset.prune_columns(4, ds), [apple_train, apple_validate, apple_test]))

# %%
# Rename labels for consistency
def rename_sentiment(sentiment):
        if sentiment in ["5", "positive"]:
            return "Positive"
        elif sentiment in ["3", "neutral"]:
            return "Neutral"
        elif sentiment in ["1", "negative"]:
            return "Negative"
        elif sentiment in ["not_relevant"]:
            return "Irrelevant"
        else:
            return sentiment

# %%
airline_train['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in airline_train['sentiment']]).set_index(airline_train.index)
airline_validate['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in airline_validate['sentiment']]).set_index(airline_validate.index)
airline_test['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in airline_test['sentiment']]).set_index(airline_test.index)

# %%
apple_train['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in apple_train['sentiment']]).set_index(apple_train.index)
apple_validate['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in apple_validate['sentiment']]).set_index(apple_validate.index)
apple_test['sentiment'] = pd.DataFrame([rename_sentiment(e) for e in apple_test['sentiment']]).set_index(apple_test.index)

# %%
# cat the datasets
train_ds = pd.concat([twitter_train,airline_train,apple_train],axis=0)
validate_ds = pd.concat([twitter_validate,airline_validate,apple_validate],axis=0)
test_ds = pd.concat([twitter_test,airline_test,apple_test],axis=0)

# %%
bert_weights_name = 'bert-base-cased'
bert_tokenizer = BertTokenizer.from_pretrained(bert_weights_name)
bert_model = BertModel.from_pretrained(bert_weights_name)
# model = BertForSequenceClassification.from_pretrained(bert_weights_name)
# Unique values of sentiment
twitter_sentiment_labels = train_ds['sentiment'].unique()

# %%
train_ds.size, validate_ds.size, test_ds.size
# Out:
# (402588, 17112, 145548)

# %%
# %%time
bert_experiment_full = sst.experiment(
    [train_ds], # 
    dataset.hf_cls_phi,
    dataset.fit_softmax_classifier,
    assess_dataframes=[validate_ds],
    vectorize=False)
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant      0.529     0.199     0.289       181
#     Negative      0.728     0.871     0.793      1297
#      Neutral      0.641     0.531     0.581       813
#     Positive      0.639     0.635     0.637       561
#
#     accuracy                          0.685      2852
#    macro avg      0.634     0.559     0.575      2852
# weighted avg      0.673     0.685     0.670      2852
#
# CPU times: user 7h 6min 22s, sys: 2min 58s, total: 7h 9min 21s
# Wall time: 1h 14min 1s

# %%
bert_experiment_full.keys()
# Out:
# dict_keys(['model', 'phi', 'train_dataset', 'assess_datasets', 'predictions', 'metric', 'scores'])

# %%
bert_experiment_full['scores']
# Out:
# [0.5750065613628772]

# %%
bert_experiment_full['metric']
# Out:
# 'safe_macro_f1'

# %%
bert_experiment_full['model']
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# # Test BERT trained on Tweets on test set

# %%
def predict_one_bert(text):
    # List of tokenized examples:
    X = [bert_experiment_full['phi'](text)]
    # Standard `predict` step on a list of lists of str:
    preds = bert_experiment_full['model'].predict(X)
    # Be sure to return the only member of the predictions,
    # rather than the singleton list:
    return preds[0]

# %%
# %% time
# twitter_test['prediction'] = twitter_test['text'].apply(predict_one_bert)

# %%
# import importlib
# importlib.reload(sst)

# %%
# %%time
bert_test = sst.evaluate(
    bert_experiment_full['model'],
    bert_experiment_full['phi'],
    assess_dataframes=[test_ds],
    vectorizer=bert_experiment_full['assess_datasets'][0]['vectorizer'],
    vectorize=False
)
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant      0.479     0.233     0.313      3911
#     Negative      0.607     0.742     0.668      7851
#      Neutral      0.549     0.524     0.536      6008
#     Positive      0.581     0.629     0.604      6488
#
#     accuracy                          0.576     24258
#    macro avg      0.554     0.532     0.530     24258
# weighted avg      0.565     0.576     0.561     24258
#
# CPU times: user 2h 24min 10s, sys: 56.7 s, total: 2h 25min 6s
# Wall time: 24min 11s

# %%
type(bert_test['predictions'][0])
# Out:
# numpy.ndarray

# %%
predictions_fname ='results/BERT_predictions_on_combined_twitter_test.csv'
df = bert_test['predictions'][0]
pd.DataFrame(df).to_csv(predictions_fname)

# %%
encoding_fname ='results/BERT_encodings_on_combined_twitter_test.csv'
encoded_test = bert_test['assess_datasets'][0]
pd.DataFrame(df).to_csv(encoding_fname)

# %%
predictions_df = pd.DataFrame(df)
predictions_df = predictions_df.set_index(test_ds.index)
predictions_df
# Out:
#              0
# 1     Negative
# 2     Negative
# 11    Positive
# 13     Neutral
# 17     Neutral
# ...        ...
# 3826  Negative
# 3835  Positive
# 3845   Neutral
# 3876   Neutral
# 3884  Negative
#
# [24258 rows x 1 columns]

# %%
test_ds['BERT_sentiment'] = predictions_df

# %%
test_ds
# Out:
#                 dataset   tweet_id  \
# 1     twitter_sentiment          1
# 2     twitter_sentiment          2
# 11    twitter_sentiment          3
# 13    twitter_sentiment          4
# 17    twitter_sentiment          5
# ...                 ...        ...
# 3826      twitter_apple  623499356
# 3835      twitter_apple  623499365
# 3845      twitter_apple  623499375
# 3876      twitter_apple  623499406
# 3884      twitter_apple  623499514
#
#                                                    text sentiment  entity  \
# 1     I am coming to the borders and I will kill you...  Positive  2401.0
# 2     im getting on borderlands and i will kill you ...  Positive  2401.0
# 11                                                  was  Positive  2402.0
# 13    Rock-Hard La Varlope, RARE & POWERFUL, HANDSOM...   Neutral  2403.0
# 17    I-Hard like me, RARE LONDON DE, HANDSOME 2011,...   Neutral  2403.0
# ...                                                 ...       ...     ...
# 3826  RT @iLoveMyMom98: I've tried turning it off an...  Negative     NaN
# 3835                 @afrobugeisha @Apple watch it!!!!!   Neutral     NaN
# 3845  media reports say that @Apple is hiring pros f...   Neutral     NaN
# 3876  Apple Is Warming Up To Social Media: Apple is ...   Neutral     NaN
# 3884  My iPhone 5's photos are no longer downloading...  Negative     NaN
#
#      airline BERT_sentiment
# 1        NaN       Negative
# 2        NaN       Negative
# 11       NaN       Positive
# 13       NaN        Neutral
# 17       NaN        Neutral
# ...      ...            ...
# 3826     NaN       Negative
# 3835     NaN       Positive
# 3845     NaN        Neutral
# 3876     NaN        Neutral
# 3884     NaN       Negative
#
# [24258 rows x 7 columns]

# %%
test_predictions_fname ='results/BERT_predictions_added_to_combined_twitter_test.csv'
test_ds.to_csv(test_predictions_fname)

# %%
correct = test_ds[test_ds['sentiment'] == test_ds['BERT_sentiment']]

# %%
correct
# Out:
#                 dataset   tweet_id  \
# 11    twitter_sentiment          3
# 13    twitter_sentiment          4
# 17    twitter_sentiment          5
# 19    twitter_sentiment          6
# 22    twitter_sentiment          7
# ...                 ...        ...
# 3823      twitter_apple  623499353
# 3826      twitter_apple  623499356
# 3845      twitter_apple  623499375
# 3876      twitter_apple  623499406
# 3884      twitter_apple  623499514
#
#                                                    text sentiment  entity  \
# 11                                                  was  Positive  2402.0
# 13    Rock-Hard La Varlope, RARE & POWERFUL, HANDSOM...   Neutral  2403.0
# 17    I-Hard like me, RARE LONDON DE, HANDSOME 2011,...   Neutral  2403.0
# 19    this was the first Borderlands session in a lo...  Positive  2404.0
# 22    that I was the first real borderlands session ...  Positive  2404.0
# ...                                                 ...       ...     ...
# 3823             13% left what even is this shit @apple  Negative     NaN
# 3826  RT @iLoveMyMom98: I've tried turning it off an...  Negative     NaN
# 3845  media reports say that @Apple is hiring pros f...   Neutral     NaN
# 3876  Apple Is Warming Up To Social Media: Apple is ...   Neutral     NaN
# 3884  My iPhone 5's photos are no longer downloading...  Negative     NaN
#
#      airline BERT_sentiment
# 11       NaN       Positive
# 13       NaN        Neutral
# 17       NaN        Neutral
# 19       NaN       Positive
# 22       NaN       Positive
# ...      ...            ...
# 3823     NaN       Negative
# 3826     NaN       Negative
# 3845     NaN        Neutral
# 3876     NaN        Neutral
# 3884     NaN       Negative
#
# [13963 rows x 7 columns]

# %%
incorrect = test_ds[test_ds['sentiment'] != test_ds['BERT_sentiment']]

# %%
incorrect
# Out:
#                 dataset   tweet_id  \
# 1     twitter_sentiment          1
# 2     twitter_sentiment          2
# 37    twitter_sentiment         10
# 46    twitter_sentiment         13
# 63    twitter_sentiment         16
# ...                 ...        ...
# 3770      twitter_apple  623499300
# 3775      twitter_apple  623499305
# 3778      twitter_apple  623499308
# 3790      twitter_apple  623499320
# 3835      twitter_apple  623499365
#
#                                                    text sentiment  entity  \
# 1     I am coming to the borders and I will kill you...  Positive  2401.0
# 2     im getting on borderlands and i will kill you ...  Positive  2401.0
# 37    Man Gearbox really needs to fix these disappoi...  Negative  2407.0
# 46                   Check out this big epic streamer!.   Neutral  2408.0
# 63                                                .. 45   Neutral  2411.0
# ...                                                 ...       ...     ...
# 3770  Our new @Technogym treadmills getting assemble...   Neutral     NaN
# 3775  RT @hoetbh: WHY CAN'T I JUST DATE ME WHY CAN'T...   Neutral     NaN
# 3778  #AAPL:Apple products may have Bah! Humbug! hol...  Negative     NaN
# 3790  Five Apple predictions for 2015. I disagree ab...  Positive     NaN
# 3835                 @afrobugeisha @Apple watch it!!!!!   Neutral     NaN
#
#      airline BERT_sentiment
# 1        NaN       Negative
# 2        NaN       Negative
# 37       NaN       Positive
# 46       NaN       Positive
# 63       NaN       Negative
# ...      ...            ...
# 3770     NaN       Negative
# 3775     NaN       Negative
# 3778     NaN        Neutral
# 3790     NaN        Neutral
# 3835     NaN       Positive
#
# [10295 rows x 7 columns]

# %%
irrelevant = test_ds[test_ds['sentiment'] == 'Irrelevant']
irrelevant
# Out:
#                 dataset   tweet_id  \
# 105   twitter_sentiment         27
# 106   twitter_sentiment         28
# 126   twitter_sentiment         35
# 139   twitter_sentiment         37
# 140   twitter_sentiment         38
# ...                 ...        ...
# 1832      twitter_apple  623497356
# 2300      twitter_apple  623497830
# 2457      twitter_apple  623497987
# 2572      twitter_apple  623498102
# 2988      twitter_apple  623498518
#
#                                                    text   sentiment  entity  \
# 105   Appreciate the (sonic) concepts / praxis Valen...  Irrelevant  2418.0
# 106   Appreciate by the ( sonic ) electronic concept...  Irrelevant  2418.0
# 126   Loving these new @GhostLifestyle cans!! Anyone...  Irrelevant  2422.0
# 139   How the hell are we already into Halloween mon...  Irrelevant  2424.0
# 140   How the hell are we already in Halloween month?!.  Irrelevant  2424.0
# ...                                                 ...         ...     ...
# 1832  #AAPL:BuzzFeed Is Going To Spend At Least $245...  Irrelevant     NaN
# 2300  Final #AAPL #PutCallRatios for Friday, Decembe...  Irrelevant     NaN
# 2457  Tax Reform: What to Expect From the New Congre...  Irrelevant     NaN
# 2572  #AAPL:After Decades Of Consolidation, Wall Str...  Irrelevant     NaN
# 2988  #AAPL:12 Under-the-Radar Stock Picks From Buff...  Irrelevant     NaN
#
#      airline BERT_sentiment
# 105      NaN     Irrelevant
# 106      NaN        Neutral
# 126      NaN     Irrelevant
# 139      NaN       Negative
# 140      NaN       Negative
# ...      ...            ...
# 1832     NaN        Neutral
# 2300     NaN        Neutral
# 2457     NaN        Neutral
# 2572     NaN        Neutral
# 2988     NaN        Neutral
#
# [3911 rows x 7 columns]

# %% [markdown]
# # Save Model

# %%
import pickle
model_fname = 'models/BERT_twitter_model_combined.sav'
pickle.dump(bert_experiment_full['model'], open(model_fname, 'wb'))
